# %%
import pandas as pd

# %%
winemag_dataset = pd.read_csv("winemag-data-130k-v2.csv")

# %%
winemag_dataset.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
winemag_dataset.iloc[0]
# Out:
# Unnamed: 0                                                               0
# country                                                              Italy
# description              Aromas include tropical fruit, broom, brimston...
# designation                                                   Vulkà Bianco
# points                                                                  87
# price                                                                  NaN
# province                                                 Sicily & Sardinia
# region_1                                                              Etna
# region_2                                                               NaN
# taster_name                                                  Kerin O’Keefe
# taster_twitter_handle                                         @kerinokeefe
# title                                    Nicosia 2013 Vulkà Bianco  (Etna)
# ...

# %%
winemag_dataset.iloc[:3]
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
#
#     designation  points  price           province           region_1  \
# 0  Vulkà Bianco      87    NaN  Sicily & Sardinia               Etna
# 1      Avidagos      87   15.0              Douro                NaN
# 2           NaN      87   14.0             Oregon  Willamette Valley
#
#             region_2    taster_name taster_twitter_handle  \
# 0                NaN  Kerin O’Keefe          @kerinokeefe
# 1                NaN     Roger Voss            @vossroger
# 2  Willamette Valley   Paul Gregutt           @paulgwine
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# ...

# %%
winemag_dataset.iloc[:3, 0]
# Out:
# 0    0
# 1    1
# 2    2
# Name: Unnamed: 0, dtype: int64

# %%
winemag_dataset.iloc[[0, 1, 5], 1]
# Out:
# 0       Italy
# 1    Portugal
# 5       Spain
# Name: country, dtype: object

# %%
winemag_dataset.iloc[-5:]
# Out:
#        Unnamed: 0 country                                        description  \
# 77356       77356      US  Lightly pink in color with a hint of orange, t...
# 77357       77357  France  This wine is plump, rounded and rich. Ripe hin...
# 77358       77358   Italy  Underbrush, red berry and coffee bean lead the...
# 77359       77359  France  This is a concentrated wine—firm and structure...
# 77360       77360  France  A small portion of this producer's vineyard, p...
#
#            designation  points  price    province             region_1  \
# 77356  Gesture Rose of      87   18.0  California          Paso Robles
# 77357      Les Natures      87   25.0      Alsace               Alsace
# 77358              NaN      87   25.0     Tuscany  Rosso di Montalcino
# 77359              NaN      87   20.0  Beaujolais  Beaujolais-Villages
# 77360  Vieilles Vignes      87   20.0  Beaujolais  Beaujolais-Villages
#
#             region_2       taster_name taster_twitter_handle  \
# ...

# %%
winemag_dataset.loc[0, 'country']
# Out:
# 'Italy'

# %%
winemag_dataset.loc[:, ['taster_name', 'taster_twitter_handle', 'points']]
# Out:
#               taster_name taster_twitter_handle  points
# 0           Kerin O’Keefe          @kerinokeefe      87
# 1              Roger Voss            @vossroger      87
# 2            Paul Gregutt           @paulgwine       87
# 3      Alexander Peartree                   NaN      87
# 4            Paul Gregutt           @paulgwine       87
# ...                   ...                   ...     ...
# 77356       Matt Kettmann         @mattkettmann      87
# 77357    Anne Krebiehl MW           @AnneInVino      87
# 77358       Kerin O’Keefe          @kerinokeefe      87
# 77359          Roger Voss            @vossroger      87
# 77360          Roger Voss            @vossroger      87
#
# [77361 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['points'].plot(kind='hist', bins=20, title='points')
# ...

# %%
winemag_dataset.loc[winemag_dataset.country == 'US']
# Out:
#        Unnamed: 0 country                                        description  \
# 2               2      US  Tart and snappy, the flavors of lime flesh and...
# 3               3      US  Pineapple rind, lemon pith and orange blossom ...
# 4               4      US  Much like the regular bottling from 2012, this...
# 10             10      US  Soft, supple plum envelopes an oaky structure ...
# 12             12      US  Slightly reduced, this wine offers a chalky, t...
# ...           ...     ...                                                ...
# 77349       77349      US  This wine is 73% Cabernet Sauvignon and a whop...
# 77350       77350      US  A rare single-vineyard bottling from this tiny...
# 77351       77351      US  This wine is a blend of top sites Stoney Vine,...
# 77353       77353      US  The aromas of woodspice, vanilla and cedar are...
# 77356       77356      US  Lightly pink in color with a hint of orange, t...
#
# ...

# %%
winemag_dataset.loc[(winemag_dataset.country=='US') & (winemag_dataset.points>=90)]
# Out:
#        Unnamed: 0 country                                        description  \
# 121           121      US  The vineyard is one of the better Chardonnay s...
# 122           122      US  Defines Rockpile Zinfandel in intensity of fru...
# 124           124      US  This sophisticated wine is mostly Cabernet Sau...
# 134           134      US  Give this young Cab time in the cellar to come...
# 142           142      US  A beautiful wine, sleek, crisp and ultra-dry, ...
# ...           ...     ...                                                ...
# 77348       77348      US  Nano-produced, this wine offers aromas of herb...
# 77349       77349      US  This wine is 73% Cabernet Sauvignon and a whop...
# 77350       77350      US  A rare single-vineyard bottling from this tiny...
# 77351       77351      US  This wine is a blend of top sites Stoney Vine,...
# 77353       77353      US  The aromas of woodspice, vanilla and cedar are...
#
# ...

# %%
winemag_dataset.loc[(winemag_dataset.country=='US') | (winemag_dataset.points>90)]
# Out:
#        Unnamed: 0 country                                        description  \
# 2               2      US  Tart and snappy, the flavors of lime flesh and...
# 3               3      US  Pineapple rind, lemon pith and orange blossom ...
# 4               4      US  Much like the regular bottling from 2012, this...
# 10             10      US  Soft, supple plum envelopes an oaky structure ...
# 12             12      US  Slightly reduced, this wine offers a chalky, t...
# ...           ...     ...                                                ...
# 77350       77350      US  A rare single-vineyard bottling from this tiny...
# 77351       77351      US  This wine is a blend of top sites Stoney Vine,...
# 77352       77352   Italy  Red berry, rose and anise aromas mingle in the...
# 77353       77353      US  The aromas of woodspice, vanilla and cedar are...
# 77356       77356      US  Lightly pink in color with a hint of orange, t...
#
# ...

# %%
winemag_dataset.loc[winemag_dataset.country.isin(['US', 'Italy'])]
# Out:
#        Unnamed: 0 country                                        description  \
# 0               0   Italy  Aromas include tropical fruit, broom, brimston...
# 2               2      US  Tart and snappy, the flavors of lime flesh and...
# 3               3      US  Pineapple rind, lemon pith and orange blossom ...
# 4               4      US  Much like the regular bottling from 2012, this...
# 6               6   Italy  Here's a bright, informal red that opens with ...
# ...           ...     ...                                                ...
# 77351       77351      US  This wine is a blend of top sites Stoney Vine,...
# 77352       77352   Italy  Red berry, rose and anise aromas mingle in the...
# 77353       77353      US  The aromas of woodspice, vanilla and cedar are...
# 77356       77356      US  Lightly pink in color with a hint of orange, t...
# 77358       77358   Italy  Underbrush, red berry and coffee bean lead the...
#
# ...

# %%
winemag_dataset.loc[winemag_dataset.price.isnull()]
# Out:
#        Unnamed: 0       country  \
# 0               0         Italy
# 13             13         Italy
# 30             30        France
# 31             31         Italy
# 32             32         Italy
# ...           ...           ...
# 77234       77234  South Africa
# 77235       77235  South Africa
# 77293       77293        France
# 77319       77319        France
# 77325       77325            US
#
#                                              description  \
# 0      Aromas include tropical fruit, broom, brimston...
# 13     This is dominated by oak and oak-driven aromas...
# 30     Red cherry fruit comes laced with light tannin...
# 31     Merlot and Nero d'Avola form the base for this...
# 32     Part of the extended Calanìca series, this Gri...
# ...                                                  ...
# 77234  Winemaker: Andrea Mullineux. Named Trifecta fo...
# 77235  Winemaker: Louis Strydom. This Cabernet Sauvig...
# ...

# %%
winemag_dataset.shape
# Out:
# (77361, 14)

# %%
winemag_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77361 entries, 0 to 77360
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             77361 non-null  int64
#  1   country                77326 non-null  object
#  2   description            77361 non-null  object
#  3   designation            55005 non-null  object
#  4   points                 77361 non-null  int64
#  5   price                  71903 non-null  float64
#  6   province               77326 non-null  object
#  7   region_1               64754 non-null  object
#  8   region_2               29741 non-null  object
#  9   taster_name            61544 non-null  object
#  10  taster_twitter_handle  58672 non-null  object
#  11  title                  77361 non-null  object
#  12  variety                77361 non-null  object
#  13  winery                 77361 non-null  object
# ...

# %%
winemag_dataset.describe()
# Out:
#          Unnamed: 0        points         price
# count  77361.000000  77361.000000  71903.000000
# mean   38680.000000     88.435879     35.172399
# std    22332.341424      3.001784     38.973739
# min        0.000000     80.000000      4.000000
# 25%    19340.000000     86.000000     17.000000
# 50%    38680.000000     88.000000     25.000000
# 75%    58020.000000     91.000000     42.000000
# max    77360.000000    100.000000   2500.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['points'].plot(kind='hist', bins=20, title='points')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
winemag_dataset.isnull().sum()
# Out:
# Unnamed: 0                   0
# country                     35
# description                  0
# designation              22356
# points                       0
# price                     5458
# province                    35
# region_1                 12607
# region_2                 47620
# taster_name              15817
# taster_twitter_handle    18689
# title                        0
# variety                      0
# winery                       0
# dtype: int64

# %%
winemag_dataset.duplicated().sum()
# Out:
# 0

# %%
winemag_dataset.groupby('province').sum()
# Out:
#                            Unnamed: 0  \
# province
# Achaia                         124624
# Aconcagua Costa                582587
# Aconcagua Valley              2639927
# Aegean                         651379
# Agioritikos                    171876
# ...                               ...
# Zenata                         474436
# Österreichischer Perlwein       59653
# Österreichischer Sekt         1469416
# Štajerska                      755537
# Župa                           314906
#
#                                                                      country  \
# province
# Achaia                                                          GreeceGreece
# Aconcagua Costa            ChileChileChileChileChileChileChileChileChileC...
# Aconcagua Valley           ChileChileChileChileChileChileChileChileChileC...
# Aegean                     TurkeyTurkeyTurkeyTurkeyTurkeyTurkeyTurkeyTurk...
# Agioritikos                                               GreeceGreeceGreece
# ...

# %%
winemag_dataset.isna().sum()
# Out:
# Unnamed: 0                   0
# country                     35
# description                  0
# designation              22356
# points                       0
# price                     5458
# province                    35
# region_1                 12607
# region_2                 47620
# taster_name              15817
# taster_twitter_handle    18689
# title                        0
# variety                      0
# winery                       0
# dtype: int64

# %%
winemag_dataset.price
# Out:
# 0         NaN
# 1        15.0
# 2        14.0
# 3        13.0
# 4        65.0
#          ...
# 77356    18.0
# 77357    25.0
# 77358    25.0
# 77359    20.0
# 77360    20.0
# Name: price, Length: 77361, dtype: float64

# %%
winemag_dataset['index_backwards'] = range(len(winemag_dataset), 0, -1)

# %%
winemag_dataset['index_backwards']
# Out:
# 0        77361
# 1        77360
# 2        77359
# 3        77358
# 4        77357
#          ...
# 77356        5
# 77357        4
# 77358        3
# 77359        2
# 77360        1
# Name: index_backwards, Length: 77361, dtype: int64
